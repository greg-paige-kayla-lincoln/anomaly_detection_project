# %%
import pandas as pd

# %%
df = pd.read_csv('anonymized-curriculum-access.csv', sep = ' ')

# %%
df
# Out:
#         2018-01-26  09:55:03  \
# 0       2018-01-26  09:56:02
# 1       2018-01-26  09:56:05
# 2       2018-01-26  09:56:06
# 3       2018-01-26  09:56:24
# 4       2018-01-26  09:56:41
# ...            ...       ...
# 900217  2021-04-21  16:41:51
# 900218  2021-04-21  16:42:02
# 900219  2021-04-21  16:42:09
# 900220  2021-04-21  16:44:37
# 900221  2021-04-21  16:44:39
#
#                                                        /      1     8  \
# 0                                                java-ii    1.0   8.0
# 1                    java-ii/object-oriented-programming    1.0   8.0
# 2                     slides/object_oriented_programming    1.0   8.0
# 3                              javascript-i/conditionals    2.0  22.0
# 4                                     javascript-i/loops    2.0  22.0
# ...                                                  ...    ...   ...
# 900217                              jquery/personal-site   64.0  28.0
# ...
