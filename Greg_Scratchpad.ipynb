# %%
import pandas as pd

# %%
df = pd.read_csv('anonymized_curriculum_access.csv', sep = ' ')

# %%
df
# Out:
#               date      time  \
# 0       2018-01-26  09:55:03
# 1       2018-01-26  09:56:02
# 2       2018-01-26  09:56:05
# 3       2018-01-26  09:56:06
# 4       2018-01-26  09:56:24
# ...            ...       ...
# 900218  2021-04-21  16:41:51
# 900219  2021-04-21  16:42:02
# 900220  2021-04-21  16:42:09
# 900221  2021-04-21  16:44:37
# 900222  2021-04-21  16:44:39
#
#                                                      url   num1  num2  \
# 0                                                      /    1.0   8.0
# 1                                                java-ii    1.0   8.0
# 2                    java-ii/object-oriented-programming    1.0   8.0
# 3                     slides/object_oriented_programming    1.0   8.0
# 4                              javascript-i/conditionals    2.0  22.0
# ...                                                  ...    ...   ...
# 900218                              jquery/personal-site   64.0  28.0
# ...
